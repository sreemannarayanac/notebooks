# %% [markdown]
# # PySpark introduction
#
# This is a general introduction to PySpark library. This was made by watching https://youtu.be/_C8kWso4ne4

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3388/664383918.py in <module>
# ----> 1 spark = SparkSession.builder.getOrCreate()
#
# ~\.conda\envs\ds\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# ~\.conda\envs\ds\lib\site-packages\pyspark\context.py in getOrCreate(cls, conf)
#     390         with SparkContext._lock:
#     391             if SparkContext._active_spark_context is None:
# --> 392                 SparkContext(conf=conf or SparkConf())
# ...
